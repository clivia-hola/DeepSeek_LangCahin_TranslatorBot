# %%
# !pip install -q langchian
# !pip install -qU langchain-deepseek

# %%
import getpass
import os

if not os.getenv("DEEPSEEK_API_KEY"):
    os.environ["DEEPSEEK_API_KEY"] = "输入DeepSeek的API密码"  ##接入API密码

# %%
from langchain_deepseek import ChatDeepSeek

chain_llm = ChatDeepSeek(
    model="deepseek-chat",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
# !npm install localtunnel

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -q streamlit

# %%
# !streamlit run /content/drive/MyDrive/colab_files/deepseek_translator.py &>/content/st_deepseek.txt & #运行，会产生st_deepseek.txt文件

# %%
# !curl ipv4.icanhazip.com #查看地址

# %%
# !pip install -q pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("输入token") #登录https://ngrok.com/，获得authtoken

# !nohup streamlit run app.py --server.port 8501 &
url = ngrok.connect(8501).public_url
print(f"Streamlit 应用地址: {url}")
# Out:
# nohup: appending output to 'nohup.out'
# Streamlit 应用地址: https://subdentated-catachrestically-deanne.ngrok-free.dev

# %%
# !npx localtunnel --port 8502
