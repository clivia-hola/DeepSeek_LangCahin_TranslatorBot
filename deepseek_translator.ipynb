# %%
# !pip install -q langchian
# !pip install -qU langchain-deepseek

# %%
from langchain_deepseek import ChatDeepSeek

chain_llm = ChatDeepSeek(
    model="deepseek-chat",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
import getpass
import os

if not os.getenv("DEEPSEEK_API_KEY"):
    os.environ["DEEPSEEK_API_KEY"] = "sk-b1449649e46b4d1da10717f28c259ac6"

# %%
# from langchain_deepseek import ChatDeepSeek

# chain_llm = ChatDeepSeek(
#     model="deepseek-chat",
#     temperature=0,
#     max_tokens=None,
#     timeout=None,
#     max_retries=2,
# )

# %%
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 23 packages in 882ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# 2 high severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠦

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q streamlit

# %%
# !streamlit run /content/drive/MyDrive/colab_files/deepseek_translator.py &>/content/st_deepseek.txt &

# %%
# !npx localtunnel --port 8502
# Out:
# ⠙your url is: https://spotty-heads-beg.loca.lt

# %%
# !curl ipv4.icanhazip.com

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("3ATZ258zxzC7BS5Pc4TonaVFBmZ_23QMhc3bP4A2Yr7U3egAL")

# !nohup streamlit run app.py --server.port 8501 &
url = ngrok.connect(8501).public_url
print(f"Streamlit 应用地址: {url}")
# Out:
# nohup: appending output to 'nohup.out'
# Streamlit 应用地址: https://subdentated-catachrestically-deanne.ngrok-free.dev
